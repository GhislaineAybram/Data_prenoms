# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
prenoms = pd.read_csv('nat2022.csv', delimiter=";")

# %%
display(prenoms)
donnees_totales = prenoms['nombre'].sum()
print(donnees_totales, ' données disponibles')
# Out:
#         sexe        preusuel annais  nombre
# 0          1  _PRENOMS_RARES   1900    1249
# 1          1  _PRENOMS_RARES   1901    1342
# 2          1  _PRENOMS_RARES   1902    1330
# 3          1  _PRENOMS_RARES   1903    1286
# 4          1  _PRENOMS_RARES   1904    1430
# ...      ...             ...    ...     ...
# 703002     2           ZYNEB   2019       7
# 703003     2           ZYNEB   2020       8
# 703004     2           ZYNEB   2021       6
# 703005     2           ZYNEB   2022       4
# 703006     2           ZYNEB   XXXX      19
#
# [703007 rows x 4 columns]
# 88150250  données disponibles

# %%
# on renomme les colonnes
prenoms.rename(columns={'preusuel':'prénoms', 'annais':'année'}, inplace=True)

# %%
prenoms.head()
# Out:
#    sexe         prénoms année  nombre
# 0     1  _PRENOMS_RARES  1900    1249
# 1     1  _PRENOMS_RARES  1901    1342
# 2     1  _PRENOMS_RARES  1902    1330
# 3     1  _PRENOMS_RARES  1903    1286
# 4     1  _PRENOMS_RARES  1904    1430

# %%
# on affiche les types de données des colonnes
types_colonnes = prenoms.dtypes
print(types_colonnes)
# Out:
# sexe        int64
# prénoms    object
# année      object
# nombre      int64
# dtype: object

# %%
# on identifie les valeurs manquantes par colonne
print(prenoms.isnull().sum())
donnees_vides = prenoms.isnull().sum().sum()
print(donnees_vides, ' données manquantes')
# Out:
# sexe       0
# prénoms    2
# année      0
# nombre     0
# dtype: int64
# 2  données manquantes

# %%
# on retire les valeurs prénoms nulles
prenoms_sans_nuls = prenoms.dropna(subset=['prénoms'])
display(prenoms_sans_nuls)
# Out:
#         sexe         prénoms année  nombre
# 0          1  _PRENOMS_RARES  1900    1249
# 1          1  _PRENOMS_RARES  1901    1342
# 2          1  _PRENOMS_RARES  1902    1330
# 3          1  _PRENOMS_RARES  1903    1286
# 4          1  _PRENOMS_RARES  1904    1430
# ...      ...             ...   ...     ...
# 703002     2           ZYNEB  2019       7
# 703003     2           ZYNEB  2020       8
# 703004     2           ZYNEB  2021       6
# 703005     2           ZYNEB  2022       4
# 703006     2           ZYNEB  XXXX      19
#
# [703005 rows x 4 columns]

# %%
# on convertit la colonne 'année' en nombres et gestion des erreurs avec 'coerce'
prenoms['année'] = pd.to_numeric(prenoms['année'], errors='coerce')

# on repère les erreurs après la conversion
donnees_annee_nulle = prenoms[pd.isna(prenoms['année'])]

# on affiche les lignes avec des erreurs après la conversion
print("Lignes avec des erreurs après la conversion :")
print(donnees_annee_nulle)

# on somme le nb de personnes sur les lignes dont l'année est nulle (xxxx) = données regroupées
donnees_regroupees = donnees_annee_nulle['nombre'].sum()
lignes_donnees_regroupees = donnees_annee_nulle.shape[0]
print(donnees_regroupees, ' données regroupées sur', lignes_donnees_regroupees, ' lignes')

# on calcule le pourcentage de données complètes
donnees_completes = round((donnees_totales - donnees_regroupees) / donnees_totales * 100, 2)
print(donnees_completes, '% de données complètes')
# Out:
# Lignes avec des erreurs après la conversion :
#         sexe  prénoms  année  nombre
# 125        1        A    NaN      21
# 134        1    AADAM    NaN       8
# 142        1    AADEL    NaN      29
# 168        1    AADIL    NaN      38
# 174        1    AAHIL    NaN       8
# ...      ...      ...    ...     ...
# 702932     2     ZURI    NaN       6
# 702952     2  ZUZANNA    NaN      10
# 702975     2      ZYA    NaN       6
# 702987     2     ZYNA    NaN      16
# 703006     2    ZYNEB    NaN      19
#
# [38797 rows x 4 columns]
# 899958  données regroupées sur 38797  lignes
# 98.98 % de données complètes
#         sexe         prénoms   année  nombre
# 0          1  _PRENOMS_RARES  1900.0    1249
# 1          1  _PRENOMS_RARES  1901.0    1342
# 2          1  _PRENOMS_RARES  1902.0    1330
# 3          1  _PRENOMS_RARES  1903.0    1286
# 4          1  _PRENOMS_RARES  1904.0    1430
# ...      ...             ...     ...     ...
# 703002     2           ZYNEB  2019.0       7
# 703003     2           ZYNEB  2020.0       8
# 703004     2           ZYNEB  2021.0       6
# 703005     2           ZYNEB  2022.0       4
# 703006     2           ZYNEB     NaN      19
#
# [703007 rows x 4 columns]

# %%
# on fait une copie de prenoms sans les lignes où l'année n'est pas précisée (les lignes XXXX)
prenoms_annees = prenoms.dropna(subset=['année'])
display(prenoms_annees)
# Out:
#         sexe         prénoms   année  nombre
# 0          1  _PRENOMS_RARES  1900.0    1249
# 1          1  _PRENOMS_RARES  1901.0    1342
# 2          1  _PRENOMS_RARES  1902.0    1330
# 3          1  _PRENOMS_RARES  1903.0    1286
# 4          1  _PRENOMS_RARES  1904.0    1430
# ...      ...             ...     ...     ...
# 703001     2           ZYNEB  2018.0       5
# 703002     2           ZYNEB  2019.0       7
# 703003     2           ZYNEB  2020.0       8
# 703004     2           ZYNEB  2021.0       6
# 703005     2           ZYNEB  2022.0       4
#
# [664210 rows x 4 columns]

# %%
prenom_hugo = prenoms.loc[prenoms['prénoms'] == 'HUGO', :]
display(prenom_hugo)
# Out:
#         sexe prénoms   année  nombre
# 127553     1    HUGO  1900.0       6
# 127554     1    HUGO  1901.0      12
# 127555     1    HUGO  1902.0       8
# 127556     1    HUGO  1903.0      13
# 127557     1    HUGO  1904.0      18
# ...      ...     ...     ...     ...
# 127673     1    HUGO     NaN       6
# 467547     2    HUGO  2001.0       4
# 467548     2    HUGO  2004.0       3
# 467549     2    HUGO  2006.0       4
# 467550     2    HUGO     NaN      19
#
# [125 rows x 4 columns]

# %%
plt.plot(prenom_hugo['année'], prenom_hugo["nombre"])
